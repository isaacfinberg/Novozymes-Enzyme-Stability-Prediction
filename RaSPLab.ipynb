# %% [markdown]
# # <b><font color='#009e74'>Rapid protein stability prediction using deep learning representations </font></b>
#
# Preprint pipeline version for predicting protein variants **thermodynamic stability changes** ($\Delta \Delta G$) using a deep learning representation. The program, using as input a protein structure (uploaded as PDB) returns stability predictions ($\Delta \Delta G$ in kcal/mol) for each variant at each position of the query protein.
# More details can be found in: **Blaabjerg et al.:** ["Rapid protein stability prediction using deep learning representations"](https://www.biorxiv.org/content/10.1101/2022.07.14.500157v1). Source code is available on the project [Github](https://github.com/KULL-Centre/papers/tree/main/2022/ML-ddG-Blaabjerg-et-al) page.

# %% [markdown]
# ##  <b><font color='#009e74'> Reminders and Important informations:</font></b>
# - This notebook  <b><font color='#d55c00'>must</font></b> be run in a Colab GPU session (go to page menu: `Runtime`->  `Change runtime type` -> select `GPU` and confirm
# - Cells named as  <b><font color='#56b4e9'>PRELIMINARY OPERATIONS </font></b> have to be run <b><font color='#d55c00'>ONCE only at the start</font></b>  and  skipped for new predictions.
# - <b><font color='#d55c00'>ONE</font></b> single pdb at the time can be processed by the pipeline.
# - A  <b><font color='#d55c00'>new run</font></b> can be perform input direcly the new structure in the pdb upload cell and run the prediction cell again
#
# ****

# %% [markdown]
# ## <b><font color='#009e74'>PIPELINE : PRELIMINARY OPERATIONS </font></b>
# These cells should be run once at the start of the notebook
# ****

# %%
#@title <b><font color='#56b4e9'>PRELIMINARY OPERATIONS</font>: Setup enviroment and dependencies</b>

#@markdown Run this cell to install the required enviroment and dependencies

#@markdown **N.B: This cell should be run only ONCE at the START of the notebook.**
# %%bash
rm -r sample_data

#install minconda
env PYTHONPATH= &> /dev/null
MINICONDA_INSTALLER_SCRIPT=Miniconda3-py37_4.9.2-Linux-x86_64.sh &> /dev/null
MINICONDA_PREFIX=/usr/local
wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT &> /dev/null
chmod +x $MINICONDA_INSTALLER_SCRIPT &> /dev/null
./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX  &> /dev/null

rm /content/Miniconda3-py37_4.9.2-Linux-x86_64.sh

#update miniconda to latest 3.7
conda install --channel defaults conda python=3.7 --yes &> /dev/null
conda update --channel defaults --all --yes &> /dev/null

echo "-> Anaconda installed!"

#install dependencies

# install dependencies present in pip
pip install numpy==1.17.3 torch==1.2.0 biopython==1.72 matplotlib==3.1.1 pdb-tools &> /dev/null
pip install --upgrade pdb-tools &> /dev/null

# install remaining dependencies with conda
conda install  mpl-scatter-density ptitprince pdbfixer=1.5 openmm=7.3.1 -c omnia -c conda-forge -c anaconda -c defaults --yes &> /dev/null

echo "--> Extra python packages installed!"

#install svn
apt-get install -qq subversion &> /dev/null

#mkdir of necessary folders
mkdir data
mkdir data/test
mkdir data/test/predictions
mkdir data/test/predictions/raw
mkdir data/test/predictions/cleaned
mkdir data/test/predictions/parsed
mkdir output/
mkdir output/predictions

#download project folders from github

svn checkout https://github.com/KULL-Centre/papers/trunk/2022/ML-ddG-Blaabjerg-et-al/src  &> /dev/null
svn checkout https://github.com/KULL-Centre/papers/trunk/2022/ML-ddG-Blaabjerg-et-al/output/cavity_models  &> /dev/null
svn checkout https://github.com/KULL-Centre/papers/trunk/2022/ML-ddG-Blaabjerg-et-al/output/ds_models  &> /dev/null

wget -cq https://github.com/KULL-Centre/papers/raw/papers/2022/ML-ddG-Blaabjerg-et-al/data/pdb_frequencies.npz -o /content/data/pdb_frequencies.npz
wget -cq https://github.com/KULL-Centre/papers/raw/main/2022/ML-ddG-Blaabjerg-et-al/colab_additonals/colab_additional.zip

#extra files for runnin the notebooks

mv ds_models ./output/
mv cavity_models ./output/

unzip colab_additional.zip &> /dev/null
rm colab_additional.zip

mv /content/colab_additional/best_model_path.txt /content/output/cavity_models/
mv /content/colab_additional/clean_pdb.py /content/src/pdb_parser_scripts/
mv /content/colab_additional/helpers.py /content/src/
mv /content/colab_additional/pdb_frequencies.npz /content/data/

echo "---> Github data imported!"

#get and compile reduce

cd src/pdb_parser_scripts
git clone https://github.com/rlabduke/reduce.git
cd reduce/
make &> /dev/null

mv /content/colab_additional/reduce /content/src/pdb_parser_scripts/reduce/

chmod +x /content/src/pdb_parser_scripts/reduce/reduce 
echo "----> reduce installed"

rm -r /content/colab_additional
#@markdown ****
# Out:
# -> Anaconda installed!
# --> Extra python packages installed!
# ---> Github data imported!
# ----> reduce installed
# Cloning into 'reduce'...

# %%
#@title <b><font color='#56b4e9'>PRELIMINARY OPERATIONS</font>: Import python libraries, functions and setup common variables</b>

#@markdown Run this cell to import libraries and functions necessary for the pipeline.

#@markdown **N.B: This cell should be run only ONCE at the START of the notebook.**

import sys
sys.path.append("/usr/local/lib/python3.7/site-packages")

import glob
import os
import random
import pathlib
import subprocess
import numpy as np
import pandas as pd
import torch
import time
import datetime
import matplotlib
from pdbfixer import PDBFixer
from simtk.openmm.app import PDBFile
from Bio.PDB.Polypeptide import index_to_one, one_to_index
from collections import OrderedDict
from torch.utils.data import DataLoader, Dataset
from google.colab import files

sys.path.append('./src/')

from cavity_model import (
     CavityModel,
     DownstreamModel,
     ResidueEnvironment,
     ResidueEnvironmentsDataset,
)

from helpers import (
     populate_dfs_with_resenvs,
     remove_disulfides,
     fermi_transform,
     inverse_fermi_transform,
     init_lin_weights,
     ds_pred,
     cavity_to_prism,
     get_seq_from_variant,
)

from visualization import (
     hist_plot,
)

#Extra function to fix pdb

# Setup pipeline parameters
## Set seeds
np.random.seed(0)
random.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.cuda.manual_seed_all(0)
torch.backends.cudnn.enabled = False
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

## Main deep parameters
DEVICE = "cuda"  # "cpu" or "cuda"
NUM_ENSEMBLE = 10
TASK_ID = int(1)
PER_TASK = int(1)

#@markdown ****

# %% [markdown]
# ## <b><font color='#009e74'>PIPELINE : PREDICTIONS </font></b>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title <b><font color='#56b4e9'> PDB upload</font></b>

#@markdown Choose between <b><font color='#d55c00'> ONE</font></b> of the possible input sources for the target pdb and <ins>leave the other cells empty or unmarked</ins>
#@markdown - AlphaFold2 PDB via Uniprot ID:
AF_ID =''#@param {type:"string"}
#@markdown - PDB ID (imported from RCSB PDB):
PDB_ID =''#@param {type:"string"}
#@markdown - Upload custom PDB
PDB_custom =True#@param {type:"boolean"}

#@markdown

#@markdown Select target chain (default A)
# chain='' #@param {type:'string'}

# if os.path.exists("/content/query_protein.pdb"):
#     os.remove("/content/query_protein.pdb")
# if os.path.exists("/content/data/test/predictions/raw/query_protein_uniquechain.pdb"):
#     os.remove("/content/data/test/predictions/raw/query_protein_uniquechain.pdb")
# if os.path.exists("/content/data/test/predictions/cleaned/query_protein_uniquechain_clean.pdb"):
#     os.remove("/content/data/test/predictions/cleaned/query_protein_uniquechain_clean.pdb")
# if os.path.exists("/content/data/test/predictions/parsed/query_protein_uniquechain_clean_coordinate_features.npz"):
#     os.remove("/content/data/test/predictions/parsed/query_protein_uniquechain_clean_coordinate_features.npz")

# if (AF_ID !='') and (len(AF_ID)==6) : 
#     subprocess.call(['curl','-s','-f',f'https://alphafold.ebi.ac.uk/files/AF-{AF_ID}-F1-model_v2.pdb','-o','/content/query_protein.pdb'])
# elif (PDB_ID !='') and (len(PDB_ID)==4):
#     subprocess.call(['curl','-s','-f',f'https://files.rcsb.org/download/{PDB_ID}.pdb','-o','/content/query_protein.pdb'])

# elif PDB_custom:
#   print('Upload PDB file:')
#   uploaded_pdb = files.upload()
#   for fn in uploaded_pdb.keys():
#     os.rename(fn, f"/content/query_protein.pdb")
#     print('PDB file correctly loaded')

# else:
#   print(f'ERROR: any PDB uploaded, please select one of the above inputs')



#@markdown N.B. This cell will also perform preliminary operations to correcly format the uploaded PDB

## remove other chains and move to raw folder
# !pdb_selchain -"$chain" /content/query_protein.pdb | pdb_delhetatm | pdb_delres --999:0:1 | pdb_fixinsert | pdb_tidy  > /content/data/test/predictions/raw/query_protein_uniquechain.pdb
# Select PDBs to run during this task - could be simplified if we decide to set PER_TASK = 1 for all cases

pdb_input_dir = "/content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/"
input_pdbs = sorted(list(filter(lambda x: x.endswith(".pdb"), os.listdir(pdb_input_dir))))
start = (TASK_ID-1)*(PER_TASK)
end = (TASK_ID*PER_TASK)
if end > len(input_pdbs):
    end = len(input_pdbs) #avoid end index exceeding length of list
pdbs = input_pdbs#[start:end] 
pdb_names = [i.split(".")[0] for i in pdbs]
print(pdb_names)
print(f"Pre-processing PDBs ...")

for f in pdbs:
  in_clean = pdb_input_dir + f
  out_clean = "/content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/"
  in_parse = out_clean + f.split('.')[0] + '_clean.pdb'
  out_parse = "/content/drive/MyDrive/kaggle_deep_learning/final_project/parsed"
  # !python3 /content/src/pdb_parser_scripts/clean_pdb.py --pdb_file_in "$in_clean" --out_dir "$out_clean" --reduce_exe /content/src/pdb_parser_scripts/reduce/reduce #&> /dev/null
  # !python3 /content/src/pdb_parser_scripts/extract_environments.py --pdb_in "$in_parse"  --out_dir "$out_parse"  #&> /dev/null

  if os.path.exists(out_parse + '/' + f.split('.')[0] + '_clean_coordinate_features.npz'):
    print(f"Pre-processing PDBs correctly ended")
  else:
    print(f"Pre-processing PDB didn't end correcly, please check input informations")

#@markdown ****
# Out:
# Streaming output truncated to the last 5000 lines.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33341_clean.pdb: 0.36661386489868164
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33342.pdb: 2.0948257446289062
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33342_clean.pdb: 0.35651659965515137
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33343.pdb: 2.07939076423645
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33343_clean.pdb: 0.35336756706237793
# Pre-processing PDBs correctly ended
# WARNING: A  13 GLU N    H atom too close to  A  12 VAL C    by 0.0149935A
#         you may need to adjust using -METALBump or -NONMETALBump.
# WARNING: A 221 LYS NZ   H atom too close to  A 187 VAL O    by -0.104454A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A 221 LYS NZ   H atom too close to  A 221 LYS CE   by -0.152425A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A 221 LYS NZ   H atom too close to  A 187 VAL O    by -0.132668A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A 221 LYS NZ   H atom too close to  A 221 LYS CE   by -0.152425A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A 221 LYS NZ   H atom too close to  A 221 LYS CE   by -0.152425A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33344.pdb: 2.087604284286499
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33344_clean.pdb: 0.35892796516418457
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33345.pdb: 2.0452518463134766
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33345_clean.pdb: 0.36189913749694824
# Pre-processing PDBs correctly ended
# WARNING: A  91 ALA N    H atom too close to  A  90 LYS C    by 0.0168946A
#         you may need to adjust using -METALBump or -NONMETALBump.
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33346.pdb: 2.115297317504883
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33346_clean.pdb: 0.359968900680542
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33347.pdb: 2.0896177291870117
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33347_clean.pdb: 0.35308003425598145
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33348.pdb: 2.097956418991089
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33348_clean.pdb: 0.35164403915405273
# Pre-processing PDBs correctly ended
# WARNING: A  18 LYS NZ   H atom too close to  A  18 LYS CE   by -0.151693A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  18 LYS NZ   H atom too close to  A  18 LYS CE   by -0.151693A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  18 LYS NZ   H atom too close to  A 146 ASN CA   by -0.23734A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  18 LYS NZ   H atom too close to  A  18 LYS CE   by -0.151693A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  18 LYS NZ   H atom too close to  A 146 ASN CA   by -0.213569A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33349.pdb: 2.1235084533691406
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33349_clean.pdb: 0.3564615249633789
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33350.pdb: 2.0755348205566406
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33350_clean.pdb: 0.3561687469482422
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33351.pdb: 2.2914328575134277
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33351_clean.pdb: 0.3558390140533447
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33352.pdb: 2.091759443283081
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33352_clean.pdb: 0.3662090301513672
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33353.pdb: 2.0816540718078613
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33353_clean.pdb: 0.35791683197021484
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33354.pdb: 2.091154098510742
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33354_clean.pdb: 0.3682365417480469
# Pre-processing PDBs correctly ended
# WARNING: A  36 LYS NZ   H atom too close to  A  12 VAL CG1  by -0.218796A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  36 LYS NZ   H atom too close to  A  36 LYS CE   by -0.152666A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  36 LYS NZ   H atom too close to  A  36 LYS CE   by -0.152666A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  36 LYS NZ   H atom too close to  A  36 LYS CE   by -0.152666A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33355.pdb: 2.1096444129943848
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33355_clean.pdb: 0.3766922950744629
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33356.pdb: 2.12343168258667
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33356_clean.pdb: 0.36624598503112793
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33357.pdb: 2.096436023712158
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33357_clean.pdb: 0.36038637161254883
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33358.pdb: 2.0987765789031982
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33358_clean.pdb: 0.36496829986572266
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33359.pdb: 2.101933002471924
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33359_clean.pdb: 0.3481159210205078
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33360.pdb: 2.087780475616455
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33360_clean.pdb: 0.3545560836791992
# Pre-processing PDBs correctly ended
# WARNING: A  36 LYS NZ   H atom too close to  A  36 LYS CE   by -0.152221A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  36 LYS NZ   H atom too close to  A  36 LYS CE   by -0.152221A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  36 LYS NZ   H atom too close to  A  12 VAL CG1  by -0.335534A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  36 LYS NZ   H atom too close to  A  36 LYS CE   by -0.152221A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33361.pdb: 2.1407930850982666
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33361_clean.pdb: 0.3497591018676758
# Pre-processing PDBs correctly ended
# WARNING: A 221 LYS NZ   H atom too close to  A 187 VAL O    by -0.266584A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A 221 LYS NZ   H atom too close to  A 221 LYS CE   by -0.152764A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A 221 LYS NZ   H atom too close to  A 221 LYS CE   by -0.152764A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A 221 LYS NZ   H atom too close to  A 221 LYS CE   by -0.152764A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33362.pdb: 2.0904035568237305
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33362_clean.pdb: 0.3485543727874756
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33363.pdb: 2.062105178833008
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33363_clean.pdb: 0.37426185607910156
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33364.pdb: 2.077723741531372
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33364_clean.pdb: 0.3601367473602295
# Pre-processing PDBs correctly ended
# WARNING: A  18 LYS NZ   H atom too close to  A  18 LYS CE   by -0.152356A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  18 LYS NZ   H atom too close to  A  18 LYS CE   by -0.152356A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  18 LYS NZ   H atom too close to  A 146 ASN CA   by -0.588605A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  18 LYS NZ   H atom too close to  A  18 LYS CE   by -0.152356A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33365.pdb: 2.1299612522125244
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33365_clean.pdb: 0.36174511909484863
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33366.pdb: 2.131963014602661
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33366_clean.pdb: 0.35695433616638184
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33367.pdb: 2.104595184326172
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33367_clean.pdb: 0.3588099479675293
# Pre-processing PDBs correctly ended
# WARNING: A  10 THR N    H atom too close to  A   9 ALA C    by 0.00516058A
#         you may need to adjust using -METALBump or -NONMETALBump.
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33368.pdb: 2.279665470123291
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33368_clean.pdb: 0.35318994522094727
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33369.pdb: 2.0661144256591797
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33369_clean.pdb: 0.3598904609680176
# Pre-processing PDBs correctly ended
# WARNING: A  78 LYS NZ   H atom too close to  A  78 LYS CE   by -0.151672A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  78 LYS NZ   H atom too close to  A 209 TYR OH   by -0.0963214A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  78 LYS NZ   H atom too close to  A  78 LYS CE   by -0.151672A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  78 LYS NZ   H atom too close to  A  78 LYS CE   by -0.151672A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33370.pdb: 2.0914363861083984
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33370_clean.pdb: 0.3597266674041748
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33371.pdb: 2.0801236629486084
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33371_clean.pdb: 0.37097716331481934
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33372.pdb: 3.222175359725952
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33372_clean.pdb: 0.5781505107879639
# Pre-processing PDBs correctly ended
# WARNING: A  30 LYS NZ   H atom too close to  A 165 GLN OE1  by -0.0322593A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  30 LYS NZ   H atom too close to  A  30 LYS CE   by -0.152447A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  30 LYS NZ   H atom too close to  A  30 LYS CE   by -0.152447A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  30 LYS NZ   H atom too close to  A  30 LYS CE   by -0.152447A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# *WARNING*: Residues LYS 78  and GLY 79  in chain  A are too close together
#             and will be treated as a chain break
# *WARNING*: Residues LYS 78  and GLY 79  in chain  A are too close together
#             and will be treated as a chain break
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33373.pdb: 3.1143486499786377
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33373_clean.pdb: 0.5889294147491455
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33374.pdb: 2.9185791015625
# ...
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33791_clean.pdb: 0.3612523078918457
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33792.pdb: 2.095367908477783
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33792_clean.pdb: 0.36858344078063965
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33793.pdb: 2.1002674102783203
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33793_clean.pdb: 0.35843682289123535
# Pre-processing PDBs correctly ended
# WARNING: A  91 ALA N    H atom too close to  A  90 LYS C    by 0.00724659A
#         you may need to adjust using -METALBump or -NONMETALBump.
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33794.pdb: 2.1093873977661133
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33794_clean.pdb: 0.3593940734863281
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33795.pdb: 2.108031988143921
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33795_clean.pdb: 0.34920763969421387
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33796.pdb: 2.105087995529175
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33796_clean.pdb: 0.36551928520202637
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33797.pdb: 2.114093065261841
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33797_clean.pdb: 0.36922264099121094
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33798.pdb: 2.1254398822784424
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33798_clean.pdb: 0.35146188735961914
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33799.pdb: 2.1166622638702393
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33799_clean.pdb: 0.3599512577056885
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33800.pdb: 2.0915369987487793
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33800_clean.pdb: 0.35971856117248535
# Pre-processing PDBs correctly ended
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33801.pdb: 2.062673807144165
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33801_clean.pdb: 0.36601710319519043
# Pre-processing PDBs correctly ended
# WARNING: A  18 LYS NZ   H atom too close to  A  18 LYS CE   by -0.152277A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  18 LYS NZ   H atom too close to  A  29 ILE CG2  by -0.347178A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  18 LYS NZ   H atom too close to  A  18 LYS CE   by -0.152277A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  18 LYS NZ   H atom too close to  A  29 ILE CG2  by -0.125544A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# WARNING: A  18 LYS NZ   H atom too close to  A  18 LYS CE   by -0.152277A
#         if warning inappropriate, adjust the cuttoffs using -METALBump or -NONMETALBump.
# Time for cleaning /content/drive/MyDrive/kaggle_deep_learning/final_project/pdbs/33802.pdb: 2.1011757850646973
# /usr/local/lib/python3.7/site-packages/Bio/PDB/Vector.py:42: BiopythonDeprecationWarning: The module Bio.PDB.Vector has been deprecated in favor of new module Bio.PDB.vectors to solve a name collision with the class Vector. For the class Vector, and vector functions like calc_angle, import from Bio.PDB instead.
#   "import from Bio.PDB instead.", BiopythonDeprecationWarning)
# /content/src/pdb_parser_scripts/extract_environments.py:109: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   features["res_indices"] = np.array(features["res_indices"], dtype=np.int)
# Time for parsing environments from /content/drive/MyDrive/kaggle_deep_learning/final_project/cleaned/33802_clean.pdb: 0.36156606674194336
# Pre-processing PDBs correctly ended

# %%
#@title <b><font color='#56b4e9'> Pipeline RUN </font></b>

#@markdown <b><font color='#d55c00'>Execute the cell</font></b> to run the pipeline and generate **saturation mutagenesis predictions of thermodynamic stability changes** predictions

### Pre-process structure data

# Create temporary residue environment datasets to more easily match ddG data
pdb_filenames_ds = sorted(glob.glob(f"/content/drive/MyDrive/kaggle_deep_learning/final_project/parsed/*coord*"))

dataset_structure = ResidueEnvironmentsDataset(pdb_filenames_ds, transformer=None)

resenv_dataset = {}
for resenv in dataset_structure:
    if AF_ID!='':
      key = (f"--{AF_ID}--{resenv.chain_id}--{resenv.pdb_residue_number}--{index_to_one(resenv.restype_index)}--"
          )
    elif PDB_ID!='':
      key = (f"--{PDB_ID}--{resenv.chain_id}--{resenv.pdb_residue_number}--{index_to_one(resenv.restype_index)}--"
          )
    else:
      key = (f"--{'CUSTOM'}--{resenv.chain_id}--{resenv.pdb_residue_number}--{index_to_one(resenv.restype_index)}--"
          )
    resenv_dataset[key] = resenv
df_structure_no_mt = pd.DataFrame.from_dict(resenv_dataset, orient='index', columns=["resenv"])
df_structure_no_mt.reset_index(inplace=True)
df_structure_no_mt["index"]=df_structure_no_mt["index"].astype(str)
res_info = pd.DataFrame(df_structure_no_mt["index"].str.split('--').tolist(),
                        columns = ['blank','pdb_id','chain_id','pos','wt_AA', 'blank2'])

df_structure_no_mt["pdbid"] = res_info['pdb_id']
df_structure_no_mt["chainid"] = res_info['chain_id']
df_structure_no_mt["variant"] = res_info["wt_AA"] + res_info['pos'] + "X"
aa_list = ["A", "C", "D", "E", "F", "G", "H", "I", "K", "L", 
            "M", "N", "P", "Q", "R", "S", "T", "V", "W", "Y"]
df_structure = pd.DataFrame(df_structure_no_mt.values.repeat(20, axis=0), columns=df_structure_no_mt.columns)
for i in range(0, len(df_structure), 20):
    for j in range(20):
        df_structure.iloc[i+j, :]["variant"] = df_structure.iloc[i+j, :]["variant"][:-1] + aa_list[j]
df_structure.drop(columns="index", inplace=True)

# Load PDB amino acid frequencies used to approximate unfolded states
pdb_nlfs = -np.log(np.load(f"{os.getcwd()}/data/pdb_frequencies.npz")["frequencies"])

# # Add wt and mt idxs and freqs to df

df_structure["wt_idx"] = df_structure.apply(lambda row: one_to_index(row["variant"][0]), axis=1)
df_structure["mt_idx"] = df_structure.apply(lambda row: one_to_index(row["variant"][-1]), axis=1)
df_structure["wt_nlf"] = df_structure.apply(lambda row: pdb_nlfs[row["wt_idx"]], axis=1)
df_structure["mt_nlf"] = df_structure.apply(lambda row: pdb_nlfs[row["mt_idx"]], axis=1)

# %%
# Define models
best_cavity_model_path = open(f"/content/output/cavity_models/best_model_path.txt", "r").read()
cavity_model_net = CavityModel(get_latent=True).to(DEVICE)
cavity_model_net.load_state_dict(torch.load(f"{best_cavity_model_path}"))
cavity_model_net.eval()
ds_model_net = DownstreamModel().to(DEVICE)
ds_model_net.apply(init_lin_weights)
ds_model_net.eval()

###set start time
start_time = time.perf_counter()

# Make ML predictions
print(f"Starting downstream model prediction")
dataset_key="predictions"
df_ml = ds_pred(cavity_model_net,
                ds_model_net,
                df_structure,
                dataset_key,
                NUM_ENSEMBLE,
                DEVICE,
                ) 
print(f"Finished downstream model prediction")
end_time = time.perf_counter()
elapsed = datetime.timedelta(seconds = end_time - start_time)
print("Complete - prediction execution took", elapsed)

elapsed = datetime.timedelta(seconds = end_time - start_time)
print("Generating output files")
#Merge and save data with predictions

df_total = df_structure.merge(df_ml, on=['pdbid','chainid','variant'], how='outer')
#df_total["b_factors"] = df_total.apply(lambda row: row["resenv"].b_factors, axis=1)
df_total = df_total.drop("resenv", 1)
print(f"{len(df_structure)-len(df_ml)} data points dropped when matching total data with ml predictions in: {dataset_key}.")

# Parse output into separate files by pdb, print to PRISM format
for pdbid in df_total["pdbid"].unique():
    df_pdb = df_total[df_total["pdbid"]==pdbid]
    for chainid in df_pdb["chainid"].unique():
        pred_outfile = f"{os.getcwd()}/output/{dataset_key}/cavity_pred_{pdbid}_{chainid}.csv"
        print(f"Parsing predictions from pdb: {pdbid}{chainid} into {pred_outfile}")
        df_chain = df_pdb[df_pdb["chainid"]==chainid]
        df_chain = df_chain.assign(pos = df_chain["variant"].str[1:-1])
        df_chain['pos'] = pd.to_numeric(df_chain['pos'])
        first_res_no = min(df_chain["pos"])
        df_chain = df_chain.assign(wt_AA = df_chain["variant"].str[0])
        df_chain = df_chain.assign(mt_AA = df_chain["variant"].str[-1])
        seq = get_seq_from_variant(df_chain)
        df_chain.to_csv(pred_outfile, index=False)
        prism_outfile = f"/content/drive/MyDrive/kaggle_deep_learning/final_project/output/prism_cavity_{pdbid}_{chainid}.txt"

        # if (AF_ID !=''):
        #   prism_outfile = f"/content/output/{dataset_key}/prism_cavity_{AF_ID}_{chainid}.txt"
        # elif (PDB_ID !=''):
        #   prism_outfile = f"/content/output/{dataset_key}/prism_cavity_{PDB_ID}_{chainid}.txt"
        # elif PDB_custom:
        #   prism_outfile = f"/content/output/{dataset_key}/prism_cavity_XXXX_{chainid}.txt"
        cavity_to_prism(df_chain, pdbid, chainid, seq, prism_outfile)

# End timer and print result
#!rm /content/output/predictions/*xxxx*.csv
elapsed = datetime.timedelta(seconds = end_time - start_time)
print("Complete - files generated")

#@markdown ****

# %%
df_structure
# Out:
#                                                   resenv   pdbid chainid  \
# 0      <ResidueEnvironment with 37 atoms. pdb_id: 338...  CUSTOM       A
# 1      <ResidueEnvironment with 37 atoms. pdb_id: 338...  CUSTOM       A
# 2      <ResidueEnvironment with 37 atoms. pdb_id: 338...  CUSTOM       A
# 3      <ResidueEnvironment with 37 atoms. pdb_id: 338...  CUSTOM       A
# 4      <ResidueEnvironment with 37 atoms. pdb_id: 338...  CUSTOM       A
# ...                                                  ...     ...     ...
# 52675  <ResidueEnvironment with 132 atoms. pdb_id: 33...  CUSTOM       A
# 52676  <ResidueEnvironment with 132 atoms. pdb_id: 33...  CUSTOM       A
# 52677  <ResidueEnvironment with 132 atoms. pdb_id: 33...  CUSTOM       A
# 52678  <ResidueEnvironment with 132 atoms. pdb_id: 33...  CUSTOM       A
# 52679  <ResidueEnvironment with 132 atoms. pdb_id: 33...  CUSTOM       A
#
#       variant  wt_idx  mt_idx    wt_nlf    mt_nlf
# 0         V1A      17       0  2.623741  2.483982
# 1         V1C      17       1  2.623741  4.335140
# 2         V1D      17       2  2.623741  2.824680
# 3         V1E      17       3  2.623741  2.712832
# 4         V1F      17       4  2.623741  3.207937
# ...       ...     ...     ...       ...       ...
# 52675    W16S      18      15  4.250501  2.844502
# 52676    W16T      18      16  4.250501  2.896883
# 52677    W16V      18      17  4.250501  2.623741
# 52678    W16W      18      18  4.250501  4.250501
# 52679    W16Y      18      19  4.250501  3.311580
#
# [52680 rows x 8 columns]

# %%
#@title <b><font color='#56b4e9'> Download results as archive </font></b>

#@markdown Run the cell to <b><font color='#009e74'> download a .zip archive </font></b> with prediction files for the <ins>current run</ins>.

#@markdown <ins>Tick</ins> the next box if you ran multiple predictions and you want to <ins>download all of them</ins>.

download_all_predictions= False #@param {type:"boolean"}

if download_all_predictions:
  os.system( "zip -r {} {}".format( f"predictions_output_all.zip" , f"/content/output/predictions/*" ) )
  files.download(f"predictions_output_all.zip")
else:
  if (AF_ID !=''):
    os.system( "zip -r {} {}".format( f"predictions_output_{AF_ID}.zip" , f"/content/output/predictions/*{AF_ID}*" ) )
    files.download(f"predictions_output_{AF_ID}.zip")
  elif (PDB_ID !=''):
    os.system( "zip -r {} {}".format( f"predictions_output_{PDB_ID}.zip" , f"/content/output/predictions/*{PDB_ID}*" ) )
    files.download(f"predictions_output_{PDB_ID}.zip")
  else:
    os.system( "zip -r {} {}".format( f"predictions_output.zip" , f"/content/output/predictions" ) )
    files.download(f"predictions_output.zip")

  if download_all_predictions:
    os.system( "zip -r {} {}".format( f"predictions_output.zip" , f"/content/output/predictions" ) )
    files.download(f"predictions_output_all.zip")

#@markdown **P.S.: prediction files are also stored in the colab file system folder: `/output/predictions/`**
#@markdown ****

# %% [markdown]
# **Troubleshooting**
#
# - Check that the runtime type is set to GPU at "Runtime" -> "Change runtime type".
# - Try to restart the session "Runtime" -> "Factory reset runtime".
# - Check your input pdb.
#
# \\
#
# **Known problems:**
#
# - Residues with numeration index below 0 are not supported by the output file parser and thus they deleted from the pdb in the pre-processing step.
# - Insertion annotations in the pdb are not supported. Any annotations is actually deleted during the pre-processing step.
#
# \\
#
# **License:**
#
# RaSP's source code is licensed under the permissive Apache Licence, Version 2.0.
#  Additionally, this notebook uses the reduce source code which license could be find in `/content/src/pdb_parser_scripts/reduce/`
#
# \\
#
# **Bugs:**
#
# For any bugs please report the issue on the project [Github](https://github.com/KULL-Centre/papers/tree/main/2022/ML-ddG-Blaabjerg-et-al) or contact one of the listed authors in the connected [manuscript](https://www.biorxiv.org/content/10.1101/2022.07.14.500157v1).
#
# \\
#
# **Citing this work:**
#
# If you use our model please cite:
#
# Blaabjerg, L.M., Kassem, M.M., Good, L.L., Jonsson, N., Cagiada, M., Johansson, K.E., Boomsma, W., Stein, A. and Lindorff-Larsen, K., 2022. *Rapid protein stability prediction using deep learning representations*, bioRxiv. (https://doi.org/10.1101/2022.07.14.500157)
#
#
#
# ```
# @article{blaabjerg2022rapid,
#   title={Rapid protein stability prediction using deep learning representations},
#   author={Blaabjerg, Lasse M and Kassem, Maher M and Good, Lydia L and Jonsson, Nicolas and Cagiada, Matteo and Johansson, Kristoffer E and Boomsma, Wouter and Stein, Amelie and Lindorff-Larsen, Kresten},
#   journal={bioRxiv},
#   year={2022},
#   publisher={Cold Spring Harbor Laboratory}
# }
# ```
